# %%
from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(model="gemma3:1b")

# %%
res = llm.invoke("Hello, I am Aakshat. ")
print(res.content)
# Out:
# Hi Aakash! How can I assist you today? 😊
