# %%
from dotenv import load_dotenv
load_dotenv()

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
llm = ChatGoogleGenerativeAI(model="gemini-3.5-flash-lite", streaming=True)

# %%
question="Can you explain me Gen AI ?"

# %%
response = llm.stream(question)
for chunk in response:
    print(chunk.content[0]["text"], end = "") #type: ignore

# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(model="openai/gpt-oss-20b", streaming=True)

# %%
question="Can you explain me Python ?"
res = llm.stream(question)
for chunk in res:
    print(chunk.content, end="") #type:ignore
# Out:
# ### What is Python?
#
# Python is a **high‑level, general‑purpose programming language** that was created by Guido van Rossum and first released in 1991.
# It’s designed to be:
#
# - **Readable** – its syntax is clear and close to English.
# - **Easy to learn** – you can write a working script in a few lines.
# - **Extensible** – you can add new features in C/C++ or use a huge ecosystem of libraries.
# - **Portable** – runs on Windows, macOS, Linux, and many other platforms.
#
# Because of these traits, Python is used for everything from quick scripts to large‑scale web services, scientific computing, data analysis, machine learning, automation, and more.
#
# ---
#
# ## Core Concepts
#
# | Concept | What it is | Quick example |
# |---------|------------|---------------|
# | **Variables & Data Types** | Containers for values. | `x = 5` (int) <br> `name = "Alice"` (str) <br> `flag = True` (bool) |
# ...
