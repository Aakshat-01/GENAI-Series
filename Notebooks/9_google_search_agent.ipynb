# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_community.utilities import GoogleSerperAPIWrapper
from langchain_groq import ChatGroq
from langchain.agents import create_agent
from langgraph.checkpoint.memory import MemorySaver

# %%
model = ChatGroq(model="openai/gpt-oss-20b")
search = GoogleSerperAPIWrapper()

# %%
# search.run("Who won IPL 2026")

# %%
agent = create_agent(
    model=model,
    tools=[search.run],
    system_prompt="You are a agent and can search any question on Google",
    checkpointer=MemorySaver()
)

# %%
que = "Total Runs ?"
res = agent.invoke(
    {"messages":[{"role":"user", "content":que}]},
    {"configurable": {"thread_id": "1"}}
)

# %%
print(res["messages"][-1].content)
# Out:
# **IPL 2025 – Total runs scored**
#
# Across the entire 2025 season (84 matches in total), teams combined for **3,758 runs**.
#
# That figure represents the aggregate score of every innings played during the league and playoff phases of the tournament.
