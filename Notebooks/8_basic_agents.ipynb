# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_core.tools import tool

# %%
@tool
def add_numbers(a: int, b: int) :
    """
        it will return the sum of two numbers
        
        Args: 
            a: Number 1
            b: Number 2
    """
    return a + b

@tool
def mul_numbers(a: int, b: int) :
    """
        it will return the multiplication of two numbers
        
        Args: 
            a: Number 1
            b: Number 2
    """
    return a * b

# %%
add_numbers.invoke({"a":12,"b":14})
# Out:
# 26

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.agents import create_agent

# %%
llm = ChatGoogleGenerativeAI(model="gemini-3.5-flash-lite")

# %%
agent = create_agent(
    model=llm,
    tools=[add_numbers, mul_numbers],
    system_prompt= "you are a maths teacher and always use tool for calculation."
)

# %%
res= agent.invoke({"messages":[{"role":"user", "content":"What is 2+3*10"}]})

# %%
# for r in res["messages"]:
#     print(r)
#     print("\n")

# %%
print(res["messages"][-1].content)
# Out:
# [{'type': 'text', 'text': 'According to the order of operations (PEMDAS/BODMAS), we must first perform the multiplication and then the addition:\n\n1. First, multiply $3 \\times 10$, which gives **30**.\n2. Then, add $2$ to that result: $2 + 30 = \\mathbf{32}$.\n\nThe final answer is **32**.', 'extras': {'signature': 'El4KXAERTTIPbIgaQGNBiz7TYZQ+LmEDz3e+IwFyjYzeG1iUrlJzn/3Rbsix0xZkSGetLsl3PXXeT5Zzfs4ekR1ABwdc4W8+J2G0TWu1UrOVxCYjy5XBeIvfz8/vWT9h'}}]
